# %% [markdown]
# # Data Cleaning Part 3 ⚽️

# %% [markdown]
# ## Import the Libraries📚

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('D:\\Desktop\\Projects\\fifa21 raw data v2.csv')
df
# Out:
#            ID               Name                      LongName  \
# 0      158023           L. Messi                  Lionel Messi
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2      200389           J. Oblak                     Jan Oblak
# 3      192985       K. De Bruyne               Kevin De Bruyne
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...       ...                ...                           ...
# 18974  247223             Xia Ao                        Ao Xia
# 18975  258760           B. Hough                     Ben Hough
# 18976  252757        R. McKinley                Ronan McKinley
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978  252520          Zhou Xiao                     Xiao Zhou
#
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# ...

# %%
df.shape
# Out:
# (18979, 77)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %% [markdown]
# ## Create a copy Dataframe to leave original as it is

# %%
fifa = df.copy()
fifa.sample(4)
# Out:
#            ID           Name             LongName  \
# 9622   225799    D. Čanađija       Dario Čanađija
# 5481   232209     José Kanté  José Kanté Martínez
# 18348  258255        T. Bała          Tomasz Bała
# 17153  238545  F. Al Birekan     Firas Al Birekan
#
#                                                photoUrl  \
# 9622   https://cdn.sofifa.com/players/225/799/21_60.png
# 5481   https://cdn.sofifa.com/players/232/209/21_60.png
# 18348  https://cdn.sofifa.com/players/258/255/21_60.png
# 17153  https://cdn.sofifa.com/players/238/545/21_60.png
#
#                                                playerUrl   Nationality  Age  \
# 9622   http://sofifa.com/player/225799/dario-canadija...       Croatia   26
# 5481   http://sofifa.com/player/232209/jose-kante-mar...        Guinea   29
# 18348  http://sofifa.com/player/258255/tomasz-bala/21...        Poland   19
# 17153  http://sofifa.com/player/238545/firas-al-birek...  Saudi Arabia   20
#
# ...

# %% [markdown]
# ## 10. Club

# %% [markdown]
# The column `Club` displays the players Team he's in

# %%
fifa['Club'].unique()
# Out:
# array(['\n\n\n\nFC Barcelona', '\n\n\n\nJuventus',
#        '\n\n\n\nAtlético Madrid', '\n\n\n\nManchester City',
#        '\n\n\n\nParis Saint-Germain', '\n\n\n\nFC Bayern München',
#        '\n\n\n\nLiverpool', '\n\n\n\nReal Madrid', '\n\n\n\nChelsea',
#        '\n\n\n\nTottenham Hotspur', '\n\n\n\nInter', '\n\n\n\nNapoli',
#        '\n\n\n\nBorussia Dortmund', '\n\n\n\nManchester United',
#        '\n\n\n\nArsenal', '\n\n\n\nLazio', '\n\n\n\nLeicester City',
#        '\n\n\n\nBorussia Mönchengladbach', '\n\n\n\nReal Sociedad',
#        '\n\n\n\nAtalanta', '\n\n\n\nOlympique Lyonnais', '\n\n\n\nMilan',
#        '\n\n\n\nVillarreal CF', '\n\n\n\nRB Leipzig', '\n\n\n\nCagliari',
#        '\n\n\n\nAjax', '\n\n\n\nSL Benfica', '\n\n\n\nAS Monaco',
#        '\n\n\n\nWolverhampton Wanderers', '\n\n\n\nEverton',
#        '\n\n\n\nFiorentina', '\n\n\n\nFC Porto', '\n\n\n\nRC Celta',
#        '\n\n\n\nTorino', '\n\n\n\nSevilla FC', '\n\n\n\nGrêmio',
# ...

# %% [markdown]
# ### Removing empty spaces '\n'

# %%
fifa['Club'] = fifa['Club'].str.strip()
fifa['Club'].unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Atlético Madrid', 'Manchester City',
#        'Paris Saint-Germain', 'FC Bayern München', 'Liverpool',
#        'Real Madrid', 'Chelsea', 'Tottenham Hotspur', 'Inter', 'Napoli',
#        'Borussia Dortmund', 'Manchester United', 'Arsenal', 'Lazio',
#        'Leicester City', 'Borussia Mönchengladbach', 'Real Sociedad',
#        'Atalanta', 'Olympique Lyonnais', 'Milan', 'Villarreal CF',
#        'RB Leipzig', 'Cagliari', 'Ajax', 'SL Benfica', 'AS Monaco',
#        'Wolverhampton Wanderers', 'Everton', 'Fiorentina', 'FC Porto',
#        'RC Celta', 'Torino', 'Sevilla FC', 'Grêmio', 'Real Betis', 'Roma',
#        'Newcastle United', 'Eintracht Frankfurt', 'Valencia CF',
#        'Medipol Başakşehir FK', 'Inter Miami', 'Bayer 04 Leverkusen',
#        'Levante UD', 'Crystal Palace', 'Athletic Club de Bilbao',
#        'Shanghai SIPG FC', 'VfL Wolfsburg',
#        'Guangzhou Evergrande Taobao FC', 'Al Shabab',
# ...

# %% [markdown]
# ## 11. Contract

# %% [markdown]
# The column `Contract` displays the players contract details
# > The goal is to create 3 new columns that will display the start and end year of the players contract
# > for all players who are not on loan or free and to calculate the length f their contract from these
# > informations.

# %%
fifa['Contract'].unique()
# Out:
# array(['2004 ~ 2021', '2018 ~ 2022', '2014 ~ 2023', '2015 ~ 2023',
#        '2017 ~ 2022', '2017 ~ 2023', '2018 ~ 2024', '2014 ~ 2022',
#        '2018 ~ 2023', '2016 ~ 2023', '2013 ~ 2023', '2011 ~ 2023',
#        '2009 ~ 2022', '2005 ~ 2021', '2011 ~ 2021', '2015 ~ 2022',
#        '2017 ~ 2024', '2010 ~ 2024', '2012 ~ 2021', '2019 ~ 2024',
#        '2015 ~ 2024', '2017 ~ 2025', '2020 ~ 2025', '2019 ~ 2023',
#        '2008 ~ 2023', '2015 ~ 2021', '2020 ~ 2022', '2012 ~ 2022',
#        '2016 ~ 2025', '2013 ~ 2022', '2011 ~ 2022', '2012 ~ 2024',
#        '2016 ~ 2021', '2012 ~ 2023', '2008 ~ 2022', '2019 ~ 2022',
#        '2017 ~ 2021', '2013 ~ 2024', '2020 ~ 2024', '2010 ~ 2022',
#        '2020 ~ 2021', '2011 ~ 2024', '2020 ~ 2023', '2014 ~ 2024',
#        '2013 ~ 2026', '2016 ~ 2022', '2010 ~ 2021', '2013 ~ 2021',
#        '2019 ~ 2025', '2018 ~ 2025', '2016 ~ 2024', '2018 ~ 2021',
#        '2009 ~ 2024', '2007 ~ 2022', 'Jun 30, 2021 On Loan',
# ...

# %%
for index, row in fifa.iterrows():
    if 'On Loan' in row['Contract'] or 'Free' in row['Contract']:
        print(row['Contract'])
# Out:
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Dec 31, 2020 On Loan
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Jan 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Dec 31, 2020 On Loan
# Jun 30, 2021 On Loan
# ...

# %%
def extract_contract_info(contract):
    if contract == 'Free' or 'On Loan' in contract:
        starting_date = np.nan
        end_date = np.nan
        contract_length = 0
    else:
        starting_date, end_date = contract.split(' ~ ')
        starting_year = int(starting_date[:4])
        end_year = int(end_date[:4])
        contract_length = int(end_year - starting_year)
    return starting_date, end_date, int(contract_length)

# Apply this to contract column and get the new columns in
new_cols = ['Contract Start', 'Contract End', 'Contract Length(years)']
new_data = fifa['Contract'].apply(lambda x: pd.Series(extract_contract_info(x)))

for i in range(len(new_cols)):
    fifa.insert(loc=fifa.columns.get_loc('Contract')+1+i, column = new_cols[i], value = new_data[i])

# %%
fifa[['Contract', 'Contract Start', 'Contract End', 'Contract Length(years)']].sample(3)
# Out:
#           Contract Contract Start Contract End  Contract Length(years)
# 14845  2020 ~ 2023           2020         2023                     3.0
# 11991  2019 ~ 2023           2019         2023                     4.0
# 11191  2019 ~ 2024           2019         2024                     5.0

# %%
# adding a contract categorization for better data handling
def contract_categorizing(contract):
    if contract == 'Free':
        return 'Free'
    elif 'On Loan' in contract:
        return 'On Loan'
    else:
        return 'Contract'

# adding contract_status column
fifa.insert(fifa.columns.get_loc('Contract Length(years)')+1, 'Contract Status', fifa['Contract'].apply(contract_categorizing))
pd.set_option('display.max_columns', None) 
fifa.sample(3)
# Out:
#            ID           Name                 LongName  \
# 617    202935         Álvaro  Álvaro González Soberón
# 4268   225673  K. Adams Nuhu         Kasim Adams Nuhu
# 16550  246467     A. Youssef              Ali Youssef
#
#                                                photoUrl  \
# 617    https://cdn.sofifa.com/players/202/935/21_60.png
# 4268   https://cdn.sofifa.com/players/225/673/21_60.png
# 16550  https://cdn.sofifa.com/players/246/467/21_60.png
#
#                                                playerUrl Nationality  Age  \
# 617    http://sofifa.com/player/202935/alvaro-gonzale...       Spain   30
# 4268   http://sofifa.com/player/225673/kasim-adams-nu...       Ghana   25
# 16550  http://sofifa.com/player/246467/ali-youssef/21...      Sweden   19
#
#        ↓OVA  POT                    Club     Contract Contract Start  \
# 617      79   79  Olympique de Marseille  2020 ~ 2023           2020
# 4268     71   74     TSG 1899 Hoffenheim  2018 ~ 2023           2018
# ...

# %%
fifa[['Contract', 'Contract Start', 'Contract End', 'Contract Length(years)', 'Contract Status']].sample(12)
# Out:
#           Contract Contract Start Contract End  Contract Length(years)  \
# 830    2020 ~ 2023           2020         2023                     3.0
# 2720   2015 ~ 2022           2015         2022                     7.0
# 5389   2019 ~ 2023           2019         2023                     4.0
# 11550  2020 ~ 2023           2020         2023                     3.0
# 9657   2018 ~ 2021           2018         2021                     3.0
# 11488  2016 ~ 2021           2016         2021                     5.0
# 16843  2020 ~ 2024           2020         2024                     4.0
# 5440   2020 ~ 2022           2020         2022                     2.0
# 6392   2018 ~ 2024           2018         2024                     6.0
# 16262  2020 ~ 2023           2020         2023                     3.0
# 9663   2020 ~ 2022           2020         2022                     2.0
# 15569  2019 ~ 2021           2019         2021                     2.0
#
#       Contract Status
# ...

# %% [markdown]
# ## 13. Height

# %% [markdown]
# The column `Height` displays the player's height.

# %%
fifa['Height'].unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '6\'2"', '164cm', '198cm', '6\'3"', '6\'5"', '5\'11"',
#        '6\'4"', '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"',
#        '5\'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#        '157cm', '156cm', '202cm', '159cm', '206cm', '155cm'], dtype=object)

# %% [markdown]
# ### We need a function to convert the heights from ft to cm📏

# %%
def convert_heights(height):
    if 'cm' in height:
        return int(height.strip('cm'))
    else:
        feet, inches = height.split("'")
        total_inches = int(feet)*12 + int(inches.strip('"'))
        return round(total_inches * 2.54)
# apply to height col
fifa['Height'] = fifa['Height'].apply(convert_heights)
fifa['Height'].unique()
# Out:
# array([170, 187, 188, 181, 175, 184, 191, 178, 193, 185, 199, 173, 168,
#        176, 177, 183, 180, 189, 179, 195, 172, 182, 186, 192, 165, 194,
#        167, 196, 163, 190, 174, 169, 171, 197, 200, 166, 164, 198, 201,
#        158, 162, 161, 160, 203, 157, 156, 202, 159, 206, 155], dtype=int64)

# %%
fifa = fifa.rename(columns = {'Height': 'Height in cm'})
fifa.sample(3)
# Out:
#            ID        Name        LongName  \
# 3137   179820   L. Robles     Luis Robles
# 6262   202491  T. Carroll     Tom Carroll
# 18962  256631  B. Montaño  Brayan Montaño
#
#                                                photoUrl  \
# 3137   https://cdn.sofifa.com/players/179/820/21_60.png
# 6262   https://cdn.sofifa.com/players/202/491/21_60.png
# 18962  https://cdn.sofifa.com/players/256/631/21_60.png
#
#                                                playerUrl    Nationality  Age  \
# 3137   http://sofifa.com/player/179820/luis-robles/21...  United States   36
# 6262   http://sofifa.com/player/202491/tom-carroll/21...        England   28
# 18962  http://sofifa.com/player/256631/brayan-montano...       Colombia   18
#
#        ↓OVA  POT                 Club     Contract Contract Start  \
# 3137     72   72          Inter Miami  2019 ~ 2020           2019
# 6262     69   69  Queens Park Rangers  2020 ~ 2021           2020
# ...

# %% [markdown]
# ## 14. Weight

# %% [markdown]
# ### This column displays the players weight, the problem is that some are in lb and most of them in kg!🏋️‍♂️

# %%
fifa['Weight'].unique()
# Out:
# array(['72kg', '83kg', '87kg', '70kg', '68kg', '80kg', '71kg', '91kg',
#        '73kg', '85kg', '92kg', '69kg', '84kg', '96kg', '81kg', '82kg',
#        '75kg', '86kg', '89kg', '74kg', '76kg', '64kg', '78kg', '90kg',
#        '66kg', '60kg', '94kg', '79kg', '67kg', '65kg', '59kg', '61kg',
#        '93kg', '88kg', '97kg', '77kg', '62kg', '63kg', '95kg', '100kg',
#        '58kg', '183lbs', '179lbs', '172lbs', '196lbs', '176lbs', '185lbs',
#        '170lbs', '203lbs', '168lbs', '161lbs', '146lbs', '130lbs',
#        '190lbs', '174lbs', '148lbs', '165lbs', '159lbs', '192lbs',
#        '181lbs', '139lbs', '154lbs', '157lbs', '163lbs', '98kg', '103kg',
#        '99kg', '102kg', '56kg', '101kg', '57kg', '55kg', '104kg', '107kg',
#        '110kg', '53kg', '50kg', '54kg', '52kg'], dtype=object)

# %%
# weight converter function
def convert_weight(weight):
    if 'kg' in weight:
        return int(weight.strip('kg'))
    else:
        pounds = int(weight.strip('lbs'))
        return round(pounds / 2.205) 

# apply the function
fifa['Weight'] = fifa['Weight'].apply(convert_weight)
fifa['Weight'].unique()
# Out:
# array([ 72,  83,  87,  70,  68,  80,  71,  91,  73,  85,  92,  69,  84,
#         96,  81,  82,  75,  86,  89,  74,  76,  64,  78,  90,  66,  60,
#         94,  79,  67,  65,  59,  61,  93,  88,  97,  77,  62,  63,  95,
#        100,  58,  98, 103,  99, 102,  56, 101,  57,  55, 104, 107, 110,
#         53,  50,  54,  52], dtype=int64)

# %%
fifa = fifa.rename(columns = {'Weight': 'Weight in kg'})
fifa.sample(3)
# Out:
#            ID              Name                          LongName  \
# 17914  243269          A. Doğan                        Adem Doğan
# 16426  251276  N. Alexandersson                Noah Alexandersson
# 1346   230348     Lafortiscinho  Erick Sebastião Laforte Medeiros
#
#                                                photoUrl  \
# 17914  https://cdn.sofifa.com/players/243/269/21_60.png
# 16426  https://cdn.sofifa.com/players/251/276/21_60.png
# 1346   https://cdn.sofifa.com/players/230/348/21_60.png
#
#                                                playerUrl Nationality  Age  \
# 17914  http://sofifa.com/player/243269/adem-dogan/210...      Turkey   18
# 16426  http://sofifa.com/player/251276/noah-alexander...      Sweden   18
# 1346   http://sofifa.com/player/230348/erick-sebastia...      Brazil   28
#
#        ↓OVA  POT          Club     Contract Contract Start Contract End  \
# 17914    54   70   Kayserispor  2017 ~ 2023           2017         2023
# ...

# %% [markdown]
# ## 19. Loan Date End

# %% [markdown]
# This column displays when the players Loan contract runs out.

# %%
fifa['Loan Date End'].unique()
# Out:
# array([nan, '30-Jun-21', '31-Dec-20', '30-Jan-21', '30-Jun-22',
#        '31-May-21', '05-Jul-21', '31-Dec-21', '01-Jul-21', '01-Jan-21',
#        '31-Aug-21', '31-Jan-21', '30-Dec-21', '23-Jun-21', '03-Jan-21',
#        '27-Nov-21', '17-Jan-21', '30-Jun-23', '31-Jul-21', '22-Nov-20',
#        '31-May-22', '30-Dec-20', '04-Jan-21', '30-Nov-20', '01-Aug-21'],
#       dtype=object)

# %%
on_loan = fifa[fifa['Contract Status'] == 'On Loan']
on_loan[['Contract','Contract Status', 'Loan Date End']]
# Out:
#                    Contract Contract Status Loan Date End
# 205    Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 248    Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 254    Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 302    Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 306    Jun 30, 2021 On Loan         On Loan     30-Jun-21
# ...                     ...             ...           ...
# 18472  Aug 31, 2021 On Loan         On Loan     31-Aug-21
# 18571  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 18600  Dec 31, 2020 On Loan         On Loan     31-Dec-20
# 18622  Dec 31, 2020 On Loan         On Loan     31-Dec-20
# 18680  Dec 31, 2020 On Loan         On Loan     31-Dec-20
#
# [1013 rows x 3 columns]

# %% [markdown]
# ## 66.W/F

# %% [markdown]
# ### Players weak foot rating out of 5🥅

# %%
fifa['W/F'].unique()
# Out:
# array(['4 ★', '3 ★', '5 ★', '2 ★', '1 ★'], dtype=object)

# %%
fifa['W/F'] = fifa['W/F'].str.replace('★','')
fifa['W/F'].unique()
# Out:
# array(['4 ', '3 ', '5 ', '2 ', '1 '], dtype=object)

# %% [markdown]
# ## 67.SM

# %% [markdown]
# ### Player's skill moves rating out of 5⚽️

# %%
fifa['SM'].unique()
# Out:
# array(['4★', '5★', '1★', '2★', '3★'], dtype=object)

# %%
fifa['SM'] = fifa['SM'].str.replace('★','')
fifa['SM'].unique()
# Out:
# array(['4', '5', '1', '2', '3'], dtype=object)

# %% [markdown]
# ## 70. IR

# %% [markdown]
# ### Player's injury resistance rating out of 5💊

# %%
fifa['IR'].unique()
# Out:
# array(['5 ★', '3 ★', '4 ★', '2 ★', '1 ★'], dtype=object)

# %%
fifa['IR'] = fifa['IR'].str.replace('★','')
fifa['IR'].unique()
# Out:
# array(['5 ', '3 ', '4 ', '2 ', '1 '], dtype=object)
